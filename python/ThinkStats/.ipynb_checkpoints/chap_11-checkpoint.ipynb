# %%
import numpy as np
import pandas as pd
import random
import pandas

import thinkstats2
import thinkplot
import first
import nsfg

# %%
import statsmodels.formula.api as smf

live, firsts, others = first.MakeFrames()
formula = 'totalwgt_lb ~ agepreg'
model = smf.ols(formula, data=live)
results = model.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            totalwgt_lb   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     43.02
# Date:                Thu, 26 Sep 2019   Prob (F-statistic):           5.72e-11
# Time:                        09:40:49   Log-Likelihood:                -15897.
# No. Observations:                9038   AIC:                         3.180e+04
# Df Residuals:                    9036   BIC:                         3.181e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      6.8304      0.068    100.470      0.000       6.697       6.964
# ...

# %%
inter = results.params['Intercept']
slope = results.params['agepreg']
inter, slope
# Out:
# (6.830396973311056, 0.017453851471802777)

# %%
slope_pvalue = results.pvalues['agepreg']
slope_pvalue
# Out:
# 5.722947107314471e-11

# %%
results.rsquared
# Out:
# 0.004738115474710258

# %%
results.f_pvalue
# Out:
# 5.722947107255698e-11

# %%
diff_weight = firsts.totalwgt_lb.mean() - others.totalwgt_lb.mean()
diff_weight
# Out:
# -0.12476118453549034

# %%
diff_age = firsts.agepreg.mean() - others.agepreg.mean()
diff_age
# Out:
# -3.586434766150152

# %%
results = smf.ols('totalwgt_lb ~ agepreg', data=live).fit()
slope = results.params['agepreg']
slope
# Out:
# 0.017453851471802777

# %%
slope * diff_age
# Out:
# -0.06259709972169447

# %%
live['isfirst'] = live.birthord == 1
formula = 'totalwgt_lb ~ isfirst'
results = smf.ols(formula, data=live).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            totalwgt_lb   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     17.74
# Date:                Thu, 26 Sep 2019   Prob (F-statistic):           2.55e-05
# Time:                        09:40:49   Log-Likelihood:                -15909.
# No. Observations:                9038   AIC:                         3.182e+04
# Df Residuals:                    9036   BIC:                         3.184e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
results = smf.ols('totalwgt_lb ~ agepreg', data=live).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            totalwgt_lb   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     43.02
# Date:                Thu, 26 Sep 2019   Prob (F-statistic):           5.72e-11
# Time:                        09:40:49   Log-Likelihood:                -15897.
# No. Observations:                9038   AIC:                         3.180e+04
# Df Residuals:                    9036   BIC:                         3.181e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      6.8304      0.068    100.470      0.000       6.697       6.964
# ...

# %%
results = smf.ols('totalwgt_lb ~ agepreg + isfirst', data=live).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            totalwgt_lb   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     24.02
# Date:                Thu, 26 Sep 2019   Prob (F-statistic):           3.95e-11
# Time:                        09:40:49   Log-Likelihood:                -15894.
# No. Observations:                9038   AIC:                         3.179e+04
# Df Residuals:                    9035   BIC:                         3.182e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
live['agepreg2'] = live.agepreg ** 2
results = smf.ols('totalwgt_lb ~ isfirst + agepreg + agepreg2', data=live).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            totalwgt_lb   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     22.64
# Date:                Thu, 26 Sep 2019   Prob (F-statistic):           1.35e-14
# Time:                        09:40:49   Log-Likelihood:                -15884.
# No. Observations:                9038   AIC:                         3.178e+04
# Df Residuals:                    9034   BIC:                         3.181e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
live = live[live.prglngth>30]
resp = nsfg.ReadFemResp()
resp.index = resp.caseid
join = live.join(resp, on='caseid', rsuffix='_r')

# %%
def GoMining(df, var):
    t = []
    for name in join.columns:
        try:
            if df[name].var() < 1e-7:
                continue
        
            formula = var + ' ~ agepreg + ' + name
            model = smf.ols(formula, data=df)
            if model.nobs < len(df)/2:
                continue
        
            results = model.fit()
        except (ValueError, TypeError):
            continue
    
        t.append((results.rsquared, name))
    return t

t = GoMining(join, 'totalwgt_lb')

# %%
t.sort(reverse=True)
for mse, name in t[:30]:
    print(name, mse)
# Out:
# totalwgt_lb 1.0
# birthwgt_lb 0.9498127305978009
# lbw1 0.3008240784470769
# prglngth 0.13012519488625063
# wksgest 0.12340041363361054
# agecon 0.10203149928156041
# mosgest 0.02714427463957969
# babysex 0.01855092529394209
# race_r 0.016199503586252995
# race 0.016199503586252995
# nbrnaliv 0.016017752709788113
# paydu 0.014003795578114597
# rmarout03 0.013430066465713209
# birthwgt_oz 0.013102457615706165
# anynurse 0.012529022541810764
# bfeedwks 0.01219368840449575
# totincr 0.011870069031173602
# marout03 0.011807801994375033
# marcon03 0.011752599354395654
# cebow 0.011437770919637047
# rmarout01 0.011407737138640184
# rmarout6 0.011354138472805753
# marout01 0.011269357246806555
# hisprace_r 0.011238349302030715
# hisprace 0.011238349302030715
# mar1diss 0.010961563590751733
# fmarcon5 0.0106049646842995
# rmarout02 0.0105469132065652
# marcon02 0.01048140179553414
# fmarout5 0.010461691367376957

# %%
varis = GoMining(join, 'prglngth')

# %%
varis.sort(reverse=True)
varis[0:35]
# Out:
# [(1.0, 'prglngth'),
#  (0.8065115675039274, 'wksgest'),
#  (0.7772278070905602, 'agecon'),
#  (0.12550330803309873, 'totalwgt_lb'),
#  (0.12067945355792009, 'birthwgt_lb'),
#  (0.10383887474318443, 'lbw1'),
#  (0.09562434659774666, 'mosgest'),
#  (0.02241842075365197, 'prglngth_i'),
#  (0.006072881692014143, 'canhaver'),
#  (0.005880867019011138, 'datcon01_i'),
#  (0.005607617892541605, 'con1mar1_i'),
#  (0.0045801411639411205, 'nbrnaliv'),
#  (0.003182814238067544, 'mar1con1_i'),
#  (0.002918483981364295, 'anynurse'),
#  (0.00256701215878008, 'bfeedwks'),
#  (0.002264199389525934, 'rmarout11_i'),
#  (0.002264199389525934, 'marout11_i'),
#  (0.002264199389525934, 'marcon11_i'),
#  (0.002249407606621512, 'pregend1'),
#  (0.002105881547474042, 'paydu'),
#  (0.002047727311564218, 'cmlastlb_r'),
#  (0.002047727311564218, 'cmlastlb'),
#  (0.0020339854256568035, 'datend02_i'),
#  (0.0020339854256568035, 'datcon02_i'),
#  (0.0020117622161547333, 'agecon02_i'),
# ...

# %%
formula = ('totalwgt_lb ~ agepreg + C(race) + babysex==1 + nbrnaliv>1 + paydu==1 + totincr')
results = smf.ols(formula, data=join).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            totalwgt_lb   R-squared:                       0.060
# Model:                            OLS   Adj. R-squared:                  0.059
# Method:                 Least Squares   F-statistic:                     79.98
# Date:                Thu, 26 Sep 2019   Prob (F-statistic):          4.86e-113
# Time:                        09:51:55   Log-Likelihood:                -14295.
# No. Observations:                8781   AIC:                         2.861e+04
# Df Residuals:                    8773   BIC:                         2.866e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
y = np.array([0, 1, 0, 1])
x1 = np.array([0, 0, 0, 1])
x2 = np.array([0, 1, 1, 1])
beta = [-1.5, 2.8, 1.1]
log_o = beta[0] + beta[1] * x1 + beta[2] * x2
log_o
# Out:
# array([-1.5, -0.4, -0.4,  2.4])

# %%
o = np.exp(log_o)
o
# Out:
# array([ 0.22313016,  0.67032005,  0.67032005, 11.02317638])

# %%
p = o / (1 + o)
p
# Out:
# array([0.18242552, 0.40131234, 0.40131234, 0.9168273 ])

# %%
likes = y * p + (1-y) * (1-p)
likes
# Out:
# array([0.81757448, 0.40131234, 0.59868766, 0.9168273 ])

# %%
like = np.prod(likes)
like
# Out:
# 0.1800933529673034

# %%
live, firsts, others = first.MakeFrames()
live = live[live.prglngth>30]
live['boy'] = (live.babysex==1).astype(int)
len(live)
# Out:
# 8884

# %%
model = smf.logit('boy ~ agepreg', data=live)
results = model.fit()
results.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.693015
#          Iterations 3
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                    boy   No. Observations:                 8884
# Model:                          Logit   Df Residuals:                     8882
# Method:                           MLE   Df Model:                            1
# Date:                Thu, 26 Sep 2019   Pseudo R-squ.:               6.144e-06
# Time:                        10:41:53   Log-Likelihood:                -6156.7
# converged:                       True   LL-Null:                       -6156.8
#                                         LLR p-value:                    0.7833
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
endog = pandas.DataFrame(model.endog, columns=[model.endog_names])
exog = pandas.DataFrame(model.exog, columns=model.exog_names)
len(exog)
# Out:
# 8782

# %%
formula = ('boy ~ agepreg + hpagelb + birthord + C(race)')
model = smf.logit(formula, data=live)
results = model.fit()
results.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.692944
#          Iterations 3
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                    boy   No. Observations:                 8782
# Model:                          Logit   Df Residuals:                     8776
# Method:                           MLE   Df Model:                            5
# Date:                Thu, 26 Sep 2019   Pseudo R-squ.:               0.0001440
# Time:                        10:49:00   Log-Likelihood:                -6085.4
# converged:                       True   LL-Null:                       -6086.3
#                                         LLR p-value:                    0.8822
# ...
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
actual = endog['boy']
baseline = actual.mean()
baseline
len(actual)
# Out:
# 8782

# %%
predict = (results.predict() >= 0.5)
true_pos = predict * actual
true_neg = (1 - predict) * (1 - actual)
true_pos.sum(), true_neg.sum(), acc
# Out:
# (3944.0, 548.0, 1.0085316569375842)

# %%
acc = (sum(true_pos) + sum(true_neg)) / len(actual)
acc
# Out:
# 0.5115007970849464

# %%
columns = ['agepreg', 'hpagelb', 'birthord', 'race']
new = pandas.DataFrame([[35, 39, 3, 2]], columns = columns)
y = results.predict(new)
y
# Out:
# 0    0.513091
# dtype: float64

# %% [markdown]
# # Exercises

# %% [markdown]
# ## 11.1

# %%
live, firsts, others = first.MakeFrames()
live = live[live.prglngth>30]

# %%
model = smf.ols('prglngth ~ birthord==1 + race==2 + nbrnaliv>1', data=live)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               prglngth   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     34.28
# Date:                Thu, 26 Sep 2019   Prob (F-statistic):           5.09e-22
# Time:                        14:49:30   Log-Likelihood:                -18247.
# No. Observations:                8884   AIC:                         3.650e+04
# Df Residuals:                    8880   BIC:                         3.653e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## 11.2

# %%
def GoMining_n(df, var):
    df['boy'] = (df.babysex==1).astype(int)
    t = []
    for name in join.columns:
        try:
            if df[name].var() < 1e-7:
                continue
        
            formula = var + ' ~ agepreg + ' + name
            model = smf.logit(formula, data=df)
            nobs = len(model.endog)
            if nobs < (len(df)/2):
                continue

            results = model.fit()
        except:
            continue
    
        t.append((results.prsquared, name))
    return t

# %%
varis = GoMining_n(join, 'boy')
# Out:
# Optimization terminated successfully.
#          Current function value: 0.692991
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.692961
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.692849
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.692996
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.692903
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.692724
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.693014
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.692992
#          Iterations 3
# Optimization terminated successfully.
#          Current function value: 0.693010
#          Iterations 3
# ...

# %%
varis.sort(reverse=True)
varis[:10]
# Out:
# [(0.009696855253233383, 'totalwgt_lb'),
#  (0.009274460080281988, 'birthwgt_lb'),
#  (0.0010985419170438382, 'constat3'),
#  (0.0010519527860076705, 'lbw1'),
#  (0.001010368752280555, 'nplaced'),
#  (0.0009096579032891183, 'fmarout5'),
#  (0.000818252143711895, 'rmarout6'),
#  (0.0008115919859909004, 'infever'),
#  (0.0007675331422082321, 'frsteatd'),
#  (0.0007334122339932581, 'splstwk1')]

# %%
formula = 'boy ~ agepreg + fmarout5==5 + infever==1'
model = smf.logit(formula, data=join)
results = model.fit()
results.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.691874
#          Iterations 4
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                    boy   No. Observations:                 8884
# Model:                          Logit   Df Residuals:                     8880
# Method:                           MLE   Df Model:                            3
# Date:                Thu, 26 Sep 2019   Pseudo R-squ.:                0.001653
# Time:                        16:49:30   Log-Likelihood:                -6146.6
# converged:                       True   LL-Null:                       -6156.8
#                                         LLR p-value:                 0.0001432
# ...
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## 11.3

# %%
formula = 'numbabes ~ agepreg + C(race) + totincr + educat'
model = smf.poisson(formula, data=join)
results = model.fit()
results.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 1.706263
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                           Poisson Regression Results
# ...
# Dep. Variable:               numbabes   No. Observations:                 8884
# Model:                        Poisson   Df Residuals:                     8878
# Method:                           MLE   Df Model:                            5
# Date:                Thu, 26 Sep 2019   Pseudo R-squ.:                 0.02006
# Time:                        16:54:09   Log-Likelihood:                -15158.
# converged:                       True   LL-Null:                       -15469.
#                                         LLR p-value:                7.374e-132
# ...
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
columns = ['agepreg', 'race', 'totincr', 'educat']
new = pandas.DataFrame([[35, 1, 14, 16]], columns=columns)
results.predict(new)
# Out:
# 0    2.648972
# dtype: float64

# %% [markdown]
# ## 11.4

# %%
formula = 'rmarital ~ agepreg + C(race) + totincr + educat'
model = smf.mnlogit(formula, data=join)
results = model.fit()
results.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 1.110519
#          Iterations 8
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                           MNLogit Regression Results
# ...
# Dep. Variable:               rmarital   No. Observations:                 8884
# Model:                        MNLogit   Df Residuals:                     8854
# Method:                           MLE   Df Model:                           25
# Date:                Thu, 26 Sep 2019   Pseudo R-squ.:                  0.1479
# Time:                        17:08:46   Log-Likelihood:                -9865.8
# converged:                       True   LL-Null:                       -11579.
#                                         LLR p-value:                     0.000
# ...
#   rmarital=2       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
columns = ['agepreg', 'race', 'totincr', 'educat']
new = pandas.DataFrame([[25, 2, 8, 14]], columns=columns)
results.predict(new)
# Out:
#           0         1         2         3         4         5
# 0  0.656612  0.072913  0.008716  0.142206  0.054188  0.065364
